# %%
from os import listdir
from os.path import isfile, join
import os
import re
import ConfigParser

config = ConfigParser.ConfigParser()
config.read('config.ini')

corpus_directory = config.get('section_directory', 'corpus_directory')

mypath = corpus_directory


doi_list = open(mypath + 'doi_list.txt', 'r+')
doi_list_edited = open(mypath + 'doi_list_edited.txt', 'w')
for line in doi_list:
    if '10.' in line:
        print(line)
        doi_list_edited.write(line)
doi_list.close()
doi_list_edited.close()
print('no error')
# Out:
# 10.1016/j.yrtph.2014.07.025
#
# 10.1371/journal.pone.0070911
#
#  10.1520/D3053.
#
# Baer, D.R., Gaspar, D.J., Nachimuthu, P., Techane, S.D., Castner, D.G., 2010.
#
# 10.1080/21681015.2014.1000403
#
# 10.1016/j.scitotenv.2015.06.100
#
# Please cite this article as: Hendren, C.O., et al., , Sci Total Environ (2015), http://dx.doi.org/10.1016/j.scitotenv.2015.06.100
#
# 10.1038/npre.2011.5883.1.
#
# Ehara, K., and H. Sakurai. 2010. Metrology of airborne
#
# 10.1186/1743-8977-11-17
#
# 10.1016/j.chemosphere.2010.11.018
#
# 10.1016/j.scitotenv.2013.12.065
#
# 10.1016/j.scitotenv.2014.09.029
#
# 10.1093/mutage/geq088
#
#  10.1021/acs.est.5b00997Environmental Science & Technology
#
# 10.1016/j.scitotenv.2014.12.025
#
# 10.1016/j.jenvman.2015.05.011
#
# 10.1016/j.colsurfa.2010.05.024
#
# 10.1016/j.jhazmat.2015.04.019
#
# 10.1016/j.trac.2011.01.009
#
# 10.1016/j.nantod.2015.04.002
#
# 10.1016/j.jcis.2011.07.017
#
# 10.1016/j.chemosphere.2015.08.024
#
# 10.1016/j.envres.2015.05.011
#
# ...
