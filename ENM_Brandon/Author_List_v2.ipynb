# %%
import requests
import json
import sys

headers = {
        'Accept': 'application/json',
        'X-ELS-APIKey': 'd5a9997b99636ca8510540b47b0b04fb',
    }

params = {
    'query': 'phosphor',
}

url = 'http://api.elsevier.com/content/search/scidir'
doi_url = 'http://api.elsevier.com/content/article/doi/'
doi_current= '10.1038/NNANO.2011.163'

r = requests.get(url, headers=headers, params=params)
print(r)
if r.status_code == 200:
    print('Request 200 OK! :D')   

    results = r.json()
    results = results['search-results']['entry']
    print(results)

    mypath = 'C:/Corpus/'

    author_list_txt = open(mypath+'author_list.txt', 'w', encoding='utf-8')

    for result in results:
        author_list_txt.write('Article:\n'+ result['dc:title'] + '\n')
        #print('Title: ' + result['dc:title'])
        #print('Author: ' + result['dc:creator'])
        
        author_list = []

        if 'authors' in result:
            authors = result['authors']['author']
            #authors = []

            #if('authors' in result):
            for item in authors:
                name = ""
                surname = ""

                if 'surname' in item:
                    surname = item['surname']
                if 'given-name' in item:
                    name = ", " + item['given-name']
                a = surname + name

                author_list.append(a)
                
            author_list_txt.write('Authors:\n')
            for a in author_list:
                author_list_txt.write(a + '\n')
            author_list_txt.write('\n---------------------------------------\n')        

            ##print('Url: ' + result['prism:url'])
            #doi_results = requests.get(doi_url + result['prism:doi'], headers=headers)
            #doi_results = doi_results.json()
            #doi_results = doi_results['full-text-retrieval-response']
            ##print result  

    author_list_txt.close()
print('done')
# Out:
# <Response [200]>
# Request 200 OK! :D
# [{'openaccess': '0', 'prism:issn': '00255408', 'prism:teaser': 'It is still a great challenge that designing proper codoping concentrations of rare earth ions for achieving intensest expected emission from the studied phosphor. In this work, the quadratic general...', 'openaccessUserLicense': None, 'prism:coverDisplayDate': 'August 2016', 'dc:title': 'Quadratic general rotary unitized design for doping concentrations and up-conversion luminescence properties of Er3+/Yb3+ co-doped NaLa(MoO4)2 phosphors', '@_fa': 'true', 'openArchiveArticle': False, 'dc:identifier': 'DOI:10.1016/j.materresbull.2015.12.030', 'prism:startingPage': '102', 'prism:issueIdentifier': None, 'openaccessArticle': False, 'eid': '1-s2.0-S0025540815302865', 'prism:coverDate': [{'@_fa': 'true', '$': '2016-08-01'}], 'authors': {'author': [{'@_fa': 'true', 'surname': 'Sun', 'given-name': 'Jiashi'}, {'@_fa': 'true', 'surname': 'Shi', 'given-name': 'Linlin'}, {'@_fa': 'true', 'surname': 'Li', 'given-name': 'Shuwei'}, {'@_fa': 'true', 'surname': 'Li', 'given-name': 'Jingjing'}, {'@_fa': 'true', 'surname': 'Li', 'given-name': 'Xiangping'}, {'@_fa': 'true', 'surname': 'Zhang', 'given-name': 'Jinsu'}, {'@_fa': 'true', 'surname': 'Cheng', 'given-name': 'Lihong'}, {'@_fa': 'true', 'surname': 'Chen', 'given-name': 'Baojiu'}]}, 'prism:doi': '10.1016/j.materresbull.2015.12.030', 'prism:url': 'http://api.elsevier.com/content/article/pii/S0025540815302865', 'prism:endingPage': '106', 'prism:publicationName': 'Materials Research Bulletin', 'pii': 'S0025-5408(15)30286-5', 'dc:creator': 'Jiashi, Sun', 'prism:volume': None, 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'http://api.elsevier.com/content/article/pii/S0025540815302865'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'http://www.sciencedirect.com/science/article/pii/S0025540815302865'}]}, {'openaccess': '0', 'prism:issn': '00255408', 'prism:teaser': 'BaWO4:Eu phosphors were prepared by performing a solvothermal reaction in a water–hexane bilayer system. A barium oleate (and europium oleate) complex was obtained in hexane via a phase transfer reaction...', 'openaccessUserLicense': None, 'prism:coverDisplayDate': 'June 2016', 'dc:title': 'Dual preparation of hydrophobic and hydrophilic BaWO4:Eu phosphors', '@_fa': 'true', 'openArchiveArticle': False, 'dc:identifier': 'DOI:10.1016/j.materresbull.2016.02.020', 'prism:startingPage': '58', 'prism:issueIdentifier': None, 'openaccessArticle': False, 'eid': '1-s2.0-S0025540816300745', 'prism:coverDate': [{'@_fa': 'true', '$': '2016-06-01'}], 'authors': {'author': [{'@_fa': 'true', 'surname': 'Cho', 'given-name': 'Young-Sik'}, {'@_fa': 'true', 'surname': 'Huh', 'given-name': 'Young-Duk'}]}, 'prism:doi': '10.1016/j.materresbull.2016.02.020', 'prism:url': 'http://api.elsevier.com/content/article/pii/S0025540816300745', 'prism:endingPage': '63', 'prism:publicationName': 'Materials Research Bulletin', 'pii': 'S0025-5408(16)30074-5', 'dc:creator': 'Young-Sik, Cho', 'prism:volume': None, 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'http://api.elsevier.com/content/article/pii/S0025540816300745'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'http://www.sciencedirect.com/science/article/pii/S0025540816300745'}]}, {'openaccess': '0', 'prism:issn': '07496036', 'prism:teaser': 'A novel green emitting Ba2CaZn2Si6O17:Eu2+ (BCZSO:Eu2+) phosphor was synthesized using conventional high temperature solid state reaction method. Powder X-ray diffraction was carried out to confirm...', 'openaccessUserLicense': None, 'prism:coverDisplayDate': 'May 2016', 'dc:title': 'Luminescence properties of a novel green emitting Ba2CaZn2Si6O17:Eu2+ phosphor for white light – Emitting diodes applications', '@_fa': 'true', 'openArchiveArticle': False, 'dc:identifier': 'DOI:10.1016/j.spmi.2016.02.045', 'prism:startingPage': '57', 'prism:issueIdentifier': None, 'openaccessArticle': False, 'eid': '1-s2.0-S074960361630088X', 'prism:coverDate': [{'@_fa': 'true', '$': '2016-05-01'}], 'authors': {'author': [{ ...
# done
